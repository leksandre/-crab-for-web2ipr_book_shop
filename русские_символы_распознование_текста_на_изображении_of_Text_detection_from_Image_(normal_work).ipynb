# %% [markdown]
# <a href="https://colab.research.google.com/github/leksandre/-crab-for-web2ipr_book_shop/blob/main/%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B5_%D1%81%D0%B8%D0%BC%D0%B2%D0%BE%D0%BB%D1%8B_%D1%80%D0%B0%D1%81%D0%BF%D0%BE%D0%B7%D0%BD%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D1%82%D0%B5%D0%BA%D1%81%D1%82%D0%B0_%D0%BD%D0%B0_%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B8_of_Text_detection_from_Image_(normal_work).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install necessary files
# !pip install easyocr #optical character recognition
# !git clone https://github.com/JaidedAI/EasyOCR.git
pip install git+https://github.com/JaidedAI/EasyOCR.git
# Out:
# ...
#   Cloning https://github.com/JaidedAI/EasyOCR.git to /tmp/pip-req-build-207hgh9l
#   Running command git clone --filter=blob:none --quiet https://github.com/JaidedAI/EasyOCR.git /tmp/pip-req-build-207hgh9l
#   Resolved https://github.com/JaidedAI/EasyOCR.git to commit c999505ef6b43be1c4ee36aa04ad979175178352
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 35.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 57.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 57.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# ...

# %%
#download the zip file
# !wget https://pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com/easy-ocr-tutorial/easy-ocr-tutorial.zip
# !unzip -qq easy-ocr-tutorial.zip
# %cd easy-ocr-tutorial
# Out:
# --2024-04-03 09:10:23--  https://pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com/easy-ocr-tutorial/easy-ocr-tutorial.zip
# Resolving pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com (pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com)... 3.5.87.128, 3.5.83.12, 3.5.78.167, ...
# Connecting to pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com (pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com)|3.5.87.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 379130 (370K) [binary/octet-stream]
# Saving to: ‘easy-ocr-tutorial.zip’
#
# easy-ocr-tutorial.z 100%[===================>] 370.24K  2.10MB/s    in 0.2s
#
# 2024-04-03 09:10:24 (2.10 MB/s) - ‘easy-ocr-tutorial.zip’ saved [379130/379130]
#
# /content/easy-ocr-tutorial

# %%
#import important packages and libraries
import cv2
import easyocr
import numpy as np
from numpy import ndarray
from google.colab.patches import cv2_imshow #cv2.imshow does not work here

# %%
#read an Image
image_path = '/content/4.jpeg'
# image_path = '/content/3.webp'
# image_path = '/content/2.jpeg'
# image_path = '/content/1.png'
    #the images (license_plate and quotepng) is upload on my Github, you may download from there
    # https://github.com/BushraAijaz/dataset/blob/main/Pakistan_-_License_Plate_-_Sindh%20(1).png
    # https://github.com/BushraAijaz/dataset/blob/main/quotepng.png
    # the image is to uploaded everytime you use this file, as I mentioned in video
img = cv2.imread(image_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1180x730>

# %%
#instant text reader
picture_read =easyocr.Reader(["ru"],gpu=False) #by default GPU is true, if you don't have GPU, type 'False'
#['en','ar']
#["ar","fa","ur","ug","en","ru"],
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.

# %%
#raw text detection on image
picture_results = picture_read.readtext(image_path)
for t in picture_results:
  print (t)
# Out:
# ([[585, 147], [647, 147], [647, 161], [585, 161]], 'полици', 0.9999462226525375)
# ([[626, 270], [692, 270], [692, 300], [626, 300]], 'ОМОН', 0.9993821382522583)
# ([[156.07152330911475, 325.6286093236459], [197.9624496759864, 321.7285398349782], [198.92847669088525, 330.3713906763541], [157.0375503240136, 333.2714601650218]], 'тои|ыл', 0.10264003714983694)
# ([[327.07152330911475, 355.6286093236459], [373.89024816297734, 346.544524195686], [375.92847669088525, 360.3713906763541], [329.10975183702266, 369.455475804314]], "'полипия", 0.3413289001371603)

# %%
# перобразуем в оттенки серого
#  img = cv2.imread(image_path)
#  gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#  cv2_imshow(gray_img)
#  cv2.imwrite('grayscale_image_opencv.jpg', gray_img)
#  picture_results = picture_read.readtext('grayscale_image_opencv.jpg')
#  for t in picture_results:
#    print (t)

# %%
#writing text and drawing box on the image

conf_threshold = 0.2
i=1
for y in picture_results:
  if y[2]> conf_threshold or True:
    print(y)
    top_left_corner= [int(value) for value in y[0][0]]
    bottom_right_corner = [int(value) for value in y[0][2]]
    text= 'text'+str(i)#y[1]
    img = cv2.rectangle(img, top_left_corner, bottom_right_corner, (255,255,255),2) #dtails of bounding box
    img =cv2.putText(img, text, top_left_corner, cv2.FONT_HERSHEY_PLAIN, 2, (255,255,0), 2) #details of text
    i = i+1

cv2_imshow(img)
# Out:
# ([[585, 147], [647, 147], [647, 161], [585, 161]], 'полици', 0.9999462226525375)
# ([[626, 270], [692, 270], [692, 300], [626, 300]], 'ОМОН', 0.9993821382522583)
# ([[156.07152330911475, 325.6286093236459], [197.9624496759864, 321.7285398349782], [198.92847669088525, 330.3713906763541], [157.0375503240136, 333.2714601650218]], 'тои|ыл', 0.10264003714983694)
# ([[327.07152330911475, 355.6286093236459], [373.89024816297734, 346.544524195686], [375.92847669088525, 360.3713906763541], [329.10975183702266, 369.455475804314]], "'полипия", 0.3413289001371603)
# <PIL.Image.Image image mode=RGB size=1180x730>
