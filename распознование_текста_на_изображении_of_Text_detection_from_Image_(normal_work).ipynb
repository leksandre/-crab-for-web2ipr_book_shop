# %% [markdown]
# <a href="https://colab.research.google.com/github/leksandre/-crab-for-web2ipr_book_shop/blob/main/%D1%80%D0%B0%D1%81%D0%BF%D0%BE%D0%B7%D0%BD%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D1%82%D0%B5%D0%BA%D1%81%D1%82%D0%B0_%D0%BD%D0%B0_%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B8_of_Text_detection_from_Image_(normal_work).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Text detection from Image using Google Notebook**
#
# 1. Install  necessary libraries
# 2. Import important packages
# 3. Read Image
# 4. TExt detection from Imgae
# 5. draw bounding box on text in image
#
# **Related Video**
#
# The explanation of this tutorial and each line in code is uploaded on youtube channel.
#
# 1. **The video title and link is:**
# Text Detection from Image using Google Notebook | EasyOCR google colab | Python Text Recognition
# https://youtu.be/8nu2IJb_RM4
#
# 2. **The channel name and link is:** Programming P++  https://www.youtube.com/@bushraaijaz2125 (Like :and subscribe for Easy Tutorials on Python, c++ and Machine Learning)

# %%
#install necessary files
# !pip install easyocr #optical character recognition

# %%
#download the zip file
# !wget https://pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com/easy-ocr-tutorial/easy-ocr-tutorial.zip
# !unzip -qq easy-ocr-tutorial.zip
# %cd easy-ocr-tutorial
# Out:
# --2024-04-03 08:44:09--  https://pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com/easy-ocr-tutorial/easy-ocr-tutorial.zip
# Resolving pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com (pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com)... 52.218.220.249, 3.5.80.199, 52.92.192.194, ...
# Connecting to pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com (pyimagesearch-code-downloads.s3-us-west-2.amazonaws.com)|52.218.220.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 379130 (370K) [binary/octet-stream]
# Saving to: ‘easy-ocr-tutorial.zip’
#
# easy-ocr-tutorial.z 100%[===================>] 370.24K  --.-KB/s    in 0.06s
#
# 2024-04-03 08:44:09 (6.34 MB/s) - ‘easy-ocr-tutorial.zip’ saved [379130/379130]
#
# /content/easy-ocr-tutorial/easy-ocr-tutorial

# %%
#import important packages and libraries
import cv2
import easyocr
import numpy as np
from numpy import ndarray
from google.colab.patches import cv2_imshow #cv2.imshow does not work here

# %%
#read an Image
image_path = '/content/3.webp'
    #the images (license_plate and quotepng) is upload on my Github, you may download from there
    # https://github.com/BushraAijaz/dataset/blob/main/Pakistan_-_License_Plate_-_Sindh%20(1).png
    # https://github.com/BushraAijaz/dataset/blob/main/quotepng.png
    # the image is to uploaded everytime you use this file, as I mentioned in video
img = cv2.imread(image_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x750>

# %%
#instant text reader
picture_read =easyocr.Reader(["ar","fa","ur","ug","en"],gpu=False) #by default GPU is true, if you don't have GPU, type 'False'
#['en','ar']
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.

# %%
#raw text detection on image
picture_results = picture_read.readtext(image_path)
for t in picture_results:
  print (t)
# Out:
# [[[306, 230], [348, 230], [348, 256], [306, 256]], 'Tle', 0.5421268253033746]
# [[[329, 283], [351, 283], [351, 303], [329, 303]], 'ب5', 0.09381457551946838]
# [[[513.8800042399873, 216.60800678397965], [578.1062479454868, 203.47983657252962], [584.1199957600127, 239.39199321602035], [518.8937520545132, 251.52016342747038]], 'The', 0.9711410403251648]
# [[[567.0776772972363, 255.21553545944727], [695.4595883951068, 221.99220316355408], [704.9223227027637, 258.78446454055273], [576.5404116048932, 291.00779683644595]], 'Hobbit', 0.7689818393481956]
# [[[301.7701175612585, 258.99310580513264], [366.4534192579023, 244.27351978147615], [372.2298824387415, 272.00689419486736], [307.5465807420977, 285.7264802185238]], 'Hobbit', 0.9997431282186429]
# [[[318.43826238111393, 307.7506099048912], [373.6695453583147, 295.89881050834566], [377.56173761888607, 318.2493900951088], [323.3304546416853, 329.10118949165434]], ']٠R٠ R', 0.13664081927779956]
# ...

# %%
#writing text and drawing box on the image

conf_threshold = 0.2
for y in picture_results:
  if y[2]> conf_threshold:
    print(y)
    top_left_corner= [int(value) for value in y[0][0]]
    bottom_right_corner = [int(value) for value in y[0][2]]
    text= y[1]
    img = cv2.rectangle(img, top_left_corner, bottom_right_corner, (0,0,255),2) #dtails of bounding box
    img =cv2.putText(img, text, top_left_corner, cv2.FONT_HERSHEY_PLAIN, 2, (255,0,0), 2) #details of text

cv2_imshow(img)
# Out:
# [[[306, 230], [348, 230], [348, 256], [306, 256]], 'Tle', 0.5421268253033746]
# [[[513.8800042399873, 216.60800678397965], [578.1062479454868, 203.47983657252962], [584.1199957600127, 239.39199321602035], [518.8937520545132, 251.52016342747038]], 'The', 0.9711410403251648]
# [[[567.0776772972363, 255.21553545944727], [695.4595883951068, 221.99220316355408], [704.9223227027637, 258.78446454055273], [576.5404116048932, 291.00779683644595]], 'Hobbit', 0.7689818393481956]
# [[[301.7701175612585, 258.99310580513264], [366.4534192579023, 244.27351978147615], [372.2298824387415, 272.00689419486736], [307.5465807420977, 285.7264802185238]], 'Hobbit', 0.9997431282186429]
# [[[325.5857864376269, 328.5857864376269], [384.7405137101429, 319.01480356029646], [387.4142135623731, 341.4142135623731], [328.2594862898571, 350.98519643970354]], 'Tolkien', 0.8543534367156437]
# <PIL.Image.Image image mode=RGB size=1200x750>
